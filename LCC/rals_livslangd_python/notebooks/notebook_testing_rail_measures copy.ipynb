# %% [markdown]
# ## Vinnova - Maintenance tables
#
# Notebook to test the main program.
#
# Version 0.1 (2025-04-28): initial conversion from Matlab.

# %% [markdown]
# ## Setting parameters

# %%
import pandas as pd # type: ignore
import seaborn as sns # type: ignore
import matplotlib.pyplot as plt # type: ignore

# %%
# Define the tonnage
tonnage = "H_32t"  # Standard axle load (30 tons), alternatively "H_32t" for heavy axle load (32.5 tons)

# Define the rail profile
rail_profile = "MB5"  # MB5 or MB6

# The actual path to your Excel file
file_path = '../data/raw/raw_data_structured.csv'

# %% [markdown]
# ## Reading input data

# %%
# Ensure the preprocessings module is accessible
import sys
sys.path.append('../')  # Adjust the path to the root directory containing 'preprocessings'

# Import the function to read the input data
from preprocessings.read_input_data import read_input_data

# Call the function to read the data
data_df = read_input_data(file_path)

# %%
data_df
# Out:
#     Profile  Condition  Gauge  Month   Value
# 0       MB5    H-index   1440      1  0.5300
# 1       MB5    H-index   1445      1  0.5300
# 2       MB5    H-index   1450      1  0.5300
# 3       MB5    H-index   1455      1  0.5300
# 4       MB6    H-index   1450      1  0.5300
# ..      ...        ...    ...    ...     ...
# 283     MB5  RCF-depth   1445     12  0.5234
# 284     MB5  RCF-depth   1450     12  0.9234
# 285     MB5  RCF-depth   1455     12  1.2440
# 286     MB6  RCF-depth   1450     12  0.8339
# 287     MB6  RCF-depth   1455     12  1.5158
#
# [288 rows x 5 columns]

# %%
from rail_analysis.rail_measures import get_h_index, get_wear_data, get_rcf_residual, get_rcf_depth

# Check if the data was loaded successfully
if data_df is None:
    print("Failed to load data. Please check the file path and format.")
else:
    # 2. Test get_h_index()
    print("\n--- Test get_h_index() ---")
    print("\n(a) Get H-index for MB5, Gauge 1440:")
    h_index_mb5_1440 = get_h_index(data_df, 'MB5', 1440)
    if h_index_mb5_1440 is not None:
        print(h_index_mb5_1440)
    else:
        print("No data found.")

    print("\n(b) Get all H-index values for MB5 (all gauges):")
    h_index_mb5_all = get_h_index(data_df, 'MB5')
    if h_index_mb5_all is not None:
        print(h_index_mb5_all)
    else:
        print("No data found.")

    # 3. Test get_wear_data()
    print("\n--- Test get_wear_data() ---")
    print("\n(a) Get Wear data for MB6, Gauge 1450:")
    wear_mb6_1450 = get_wear_data(data_df, 'MB6', 1450)
    if wear_mb6_1450 is not None:
        print(wear_mb6_1450)
    else:
        print("No data found.")

    print("\n(b) Get all Wear data for MB6 (all gauges):")
    wear_mb6_all = get_wear_data(data_df, 'MB6')
    if wear_mb6_all is not None:
        print(wear_mb6_all)
    else:
        print("No data found.")

    # 4. Test get_rcf_residual()
    print("\n--- Test get_rcf_residual() ---")
    print("\n(a) Get RCF-residual data for MB5, Gauge 1445")
    rcf_residual_mb5_1445 = get_rcf_residual(data_df, 'MB5', 1445)
    if rcf_residual_mb5_1445 is not None:
        print(rcf_residual_mb5_1445)
    else:
        print("No data found.")

    print("\n(b) Get all RCF-residual data for MB5 (all gauges)")
    rcf_residual_mb5_all = get_rcf_residual(data_df, 'MB5')
    if rcf_residual_mb5_all is not None:
        print(rcf_residual_mb5_all)
    else:
        print("No data found.")

    # 5. Test get_rcf_depth()
    print("\n--- Test get_rcf_depth() ---")
    print("\n(a) Get RCF-depth data for MB6, Gauge 1455")
    rcf_depth_mb6_1455 = get_rcf_depth(data_df, 'MB6', 1455)
    if rcf_depth_mb6_1455 is not None:
        print(rcf_depth_mb6_1455)
    else:
        print("No data found.")

    print("\n(b) Get all RCF-depth data for MB6 (all gauges)")
    rcf_depth_mb6_all = get_rcf_depth(data_df, 'MB6')
    if rcf_depth_mb6_all is not None:
        print(rcf_depth_mb6_all)
    else:
        print("No data found.")
# Out:
# --- Test get_h_index() ---
#
# (a) Get H-index for MB5, Gauge 1440:
#    Profile Condition  Gauge  Month  Value
# 0      MB5   H-index   1440      1   0.53
# 1      MB5   H-index   1440      2   0.53
# 2      MB5   H-index   1440      3   0.53
# 3      MB5   H-index   1440      4   0.53
# 4      MB5   H-index   1440      5   0.53
# 5      MB5   H-index   1440      6   0.53
# 6      MB5   H-index   1440      7   0.53
# 7      MB5   H-index   1440      8   0.73
# 8      MB5   H-index   1440      9   0.88
# 9      MB5   H-index   1440     10   0.90
# 10     MB5   H-index   1440     11   0.94
# 11     MB5   H-index   1440     12   1.01
#
# (b) Get all H-index values for MB5 (all gauges):
#    Profile Condition  Gauge  Month  Value
# 0      MB5   H-index   1440      1   0.53
# 1      MB5   H-index   1445      1   0.53
# 2      MB5   H-index   1450      1   0.53
# 3      MB5   H-index   1455      1   0.53
# 4      MB5   H-index   1440      2   0.53
# 5      MB5   H-index   1445      2   0.53
# 6      MB5   H-index   1450      2   0.53
# 7      MB5   H-index   1455      2   0.53
# 8      MB5   H-index   1440      3   0.53
# 9      MB5   H-index   1445      3   0.53
# 10     MB5   H-index   1450      3   0.53
# 11     MB5   H-index   1455      3   0.53
# 12     MB5   H-index   1440      4   0.53
# 13     MB5   H-index   1445      4   0.53
# 14     MB5   H-index   1450      4   0.53
# 15     MB5   H-index   1455      4   0.53
# 16     MB5   H-index   1440      5   0.53
# 17     MB5   H-index   1445      5   0.54
# 18     MB5   H-index   1450      5   0.53
# 19     MB5   H-index   1455      5   0.53
# 20     MB5   H-index   1440      6   0.53
# 21     MB5   H-index   1445      6   0.57
# 22     MB5   H-index   1450      6   0.53
# 23     MB5   H-index   1455      6   0.55
# 24     MB5   H-index   1440      7   0.53
# 25     MB5   H-index   1445      7   0.57
# 26     MB5   H-index   1450      7   0.81
# 27     MB5   H-index   1455      7   0.80
# 28     MB5   H-index   1440      8   0.73
# 29     MB5   H-index   1445      8   0.78
# 30     MB5   H-index   1450      8   0.90
# 31     MB5   H-index   1455      8   0.91
# 32     MB5   H-index   1440      9   0.88
# 33     MB5   H-index   1445      9   0.88
# 34     MB5   H-index   1450      9   0.94
# 35     MB5   H-index   1455      9   1.04
# 36     MB5   H-index   1440     10   0.90
# 37     MB5   H-index   1445     10   0.94
# 38     MB5   H-index   1450     10   0.96
# 39     MB5   H-index   1455     10   1.11
# 40     MB5   H-index   1440     11   0.94
# 41     MB5   H-index   1445     11   1.00
# 42     MB5   H-index   1450     11   1.06
# 43     MB5   H-index   1455     11   1.21
# 44     MB5   H-index   1440     12   1.01
# 45     MB5   H-index   1445     12   1.10
# 46     MB5   H-index   1450     12   1.11
# 47     MB5   H-index   1455     12   1.30
#
# --- Test get_wear_data() ---
#
# (a) Get Wear data for MB6, Gauge 1450:
#    Profile Condition  Gauge  Month  Value
# 0      MB6      Wear   1450      1  0.035
# 1      MB6      Wear   1450      2  0.042
# 2      MB6      Wear   1450      3  0.057
# 3      MB6      Wear   1450      4  0.074
# 4      MB6      Wear   1450      5  0.077
# 5      MB6      Wear   1450      6  0.082
# 6      MB6      Wear   1450      7  0.241
# 7      MB6      Wear   1450      8  0.333
# 8      MB6      Wear   1450      9  0.429
# 9      MB6      Wear   1450     10  0.527
# 10     MB6      Wear   1450     11  0.656
# 11     MB6      Wear   1450     12  0.725
#
# (b) Get all Wear data for MB6 (all gauges):
#    Profile Condition  Gauge  Month  Value
# 0      MB6      Wear   1450      1  0.035
# 1      MB6      Wear   1455      1  0.048
# 2      MB6      Wear   1450      2  0.042
# 3      MB6      Wear   1455      2  0.062
# 4      MB6      Wear   1450      3  0.057
# 5      MB6      Wear   1455      3  0.070
# 6      MB6      Wear   1450      4  0.074
# 7      MB6      Wear   1455      4  0.076
# 8      MB6      Wear   1450      5  0.077
# 9      MB6      Wear   1455      5  0.081
# 10     MB6      Wear   1450      6  0.082
# 11     MB6      Wear   1455      6  0.085
# 12     MB6      Wear   1450      7  0.241
# 13     MB6      Wear   1455      7  0.268
# 14     MB6      Wear   1450      8  0.333
# 15     MB6      Wear   1455      8  0.339
# 16     MB6      Wear   1450      9  0.429
# 17     MB6      Wear   1455      9  0.464
# 18     MB6      Wear   1450     10  0.527
# 19     MB6      Wear   1455     10  0.543
# 20     MB6      Wear   1450     11  0.656
# 21     MB6      Wear   1455     11  0.666
# 22     MB6      Wear   1450     12  0.725
# 23     MB6      Wear   1455     12  0.748
#
# --- Test get_rcf_residual() ---
#
# (a) Get RCF-residual data for MB5, Gauge 1445
#    Profile     Condition  Gauge  Month  Value
# 0      MB5  RCF-residual   1445      1    0.0
# 1      MB5  RCF-residual   1445      2    0.0
# 2      MB5  RCF-residual   1445      3    0.0
# 3      MB5  RCF-residual   1445      4    0.0
# 4      MB5  RCF-residual   1445      5    0.0
# 5      MB5  RCF-residual   1445      6    0.0
# 6      MB5  RCF-residual   1445      7    0.0
# 7      MB5  RCF-residual   1445      8    0.0
# 8      MB5  RCF-residual   1445      9    0.0
# 9      MB5  RCF-residual   1445     10    0.0
# 10     MB5  RCF-residual   1445     11    0.0
# 11     MB5  RCF-residual   1445     12    0.0
#
# (b) Get all RCF-residual data for MB5 (all gauges)
#    Profile     Condition  Gauge  Month  Value
# 0      MB5  RCF-residual   1440      1   0.00
# 1      MB5  RCF-residual   1445      1   0.00
# 2      MB5  RCF-residual   1450      1   0.00
# 3      MB5  RCF-residual   1455      1   0.00
# 4      MB5  RCF-residual   1440      2   0.00
# 5      MB5  RCF-residual   1445      2   0.00
# 6      MB5  RCF-residual   1450      2   0.00
# 7      MB5  RCF-residual   1455      2   0.00
# 8      MB5  RCF-residual   1440      3   0.00
# 9      MB5  RCF-residual   1445      3   0.00
# 10     MB5  RCF-residual   1450      3   0.00
# 11     MB5  RCF-residual   1455      3   0.00
# 12     MB5  RCF-residual   1440      4   0.00
# 13     MB5  RCF-residual   1445      4   0.00
# 14     MB5  RCF-residual   1450      4   0.00
# 15     MB5  RCF-residual   1455      4   0.00
# 16     MB5  RCF-residual   1440      5   0.00
# 17     MB5  RCF-residual   1445      5   0.00
# 18     MB5  RCF-residual   1450      5   0.00
# 19     MB5  RCF-residual   1455      5   0.00
# 20     MB5  RCF-residual   1440      6   0.00
# 21     MB5  RCF-residual   1445      6   0.00
# 22     MB5  RCF-residual   1450      6   0.00
# 23     MB5  RCF-residual   1455      6   0.00
# 24     MB5  RCF-residual   1440      7   0.00
# 25     MB5  RCF-residual   1445      7   0.00
# 26     MB5  RCF-residual   1450      7   0.00
# 27     MB5  RCF-residual   1455      7   0.00
# 28     MB5  RCF-residual   1440      8   0.00
# 29     MB5  RCF-residual   1445      8   0.00
# 30     MB5  RCF-residual   1450      8   0.00
# 31     MB5  RCF-residual   1455      8   0.07
# 32     MB5  RCF-residual   1440      9   0.00
# 33     MB5  RCF-residual   1445      9   0.00
# 34     MB5  RCF-residual   1450      9   0.11
# 35     MB5  RCF-residual   1455      9   0.24
# 36     MB5  RCF-residual   1440     10   0.00
# 37     MB5  RCF-residual   1445     10   0.00
# 38     MB5  RCF-residual   1450     10   0.27
# 39     MB5  RCF-residual   1455     10   0.36
# 40     MB5  RCF-residual   1440     11   0.00
# 41     MB5  RCF-residual   1445     11   0.00
# 42     MB5  RCF-residual   1450     11   0.35
# 43     MB5  RCF-residual   1455     11   0.55
# 44     MB5  RCF-residual   1440     12   0.00
# 45     MB5  RCF-residual   1445     12   0.00
# 46     MB5  RCF-residual   1450     12   0.45
# 47     MB5  RCF-residual   1455     12   0.67
#
# --- Test get_rcf_depth() ---
#
# (a) Get RCF-depth data for MB6, Gauge 1455
#    Profile  Condition  Gauge  Month   Value
# 0      MB6  RCF-depth   1455      1  0.0298
# 1      MB6  RCF-depth   1455      2  0.0693
# 2      MB6  RCF-depth   1455      3  0.0890
# 3      MB6  RCF-depth   1455      4  0.1210
# 4      MB6  RCF-depth   1455      5  0.1434
# 5      MB6  RCF-depth   1455      6  0.1739
# 6      MB6  RCF-depth   1455      7  0.3781
# 7      MB6  RCF-depth   1455      8  0.6779
# 8      MB6  RCF-depth   1455      9  0.8587
# 9      MB6  RCF-depth   1455     10  1.0953
# 10     MB6  RCF-depth   1455     11  1.2992
# 11     MB6  RCF-depth   1455     12  1.5158
#
# (b) Get all RCF-depth data for MB6 (all gauges)
#    Profile  Condition  Gauge  Month   Value
# 0      MB6  RCF-depth   1450      1  0.0150
# 1      MB6  RCF-depth   1455      1  0.0298
# 2      MB6  RCF-depth   1450      2  0.0334
# 3      MB6  RCF-depth   1455      2  0.0693
# 4      MB6  RCF-depth   1450      3  0.0515
# 5      MB6  RCF-depth   1455      3  0.0890
# 6      MB6  RCF-depth   1450      4  0.0636
# 7      MB6  RCF-depth   1455      4  0.1210
# 8      MB6  RCF-depth   1450      5  0.0778
# 9      MB6  RCF-depth   1455      5  0.1434
# 10     MB6  RCF-depth   1450      6  0.0959
# 11     MB6  RCF-depth   1455      6  0.1739
# 12     MB6  RCF-depth   1450      7  0.2179
# 13     MB6  RCF-depth   1455      7  0.3781
# 14     MB6  RCF-depth   1450      8  0.3790
# 15     MB6  RCF-depth   1455      8  0.6779
# 16     MB6  RCF-depth   1450      9  0.5314
# 17     MB6  RCF-depth   1455      9  0.8587
# 18     MB6  RCF-depth   1450     10  0.6428
# 19     MB6  RCF-depth   1455     10  1.0953
# 20     MB6  RCF-depth   1450     11  0.7548
# 21     MB6  RCF-depth   1455     11  1.2992
# 22     MB6  RCF-depth   1450     12  0.8339
# 23     MB6  RCF-depth   1455     12  1.5158
